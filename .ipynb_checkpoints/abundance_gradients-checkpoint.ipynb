# %% [markdown]
# # Determine sample properties needed to measure abundance gradients

# %%
import numpy as np

from astropy import units, coordinates
from tqdm import tqdm
import os
import pandas as pd
from scipy.stats import binned_statistic_2d, binned_statistic_dd
from astropy.table import Table

import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('figure_style.mplstyle')

from my_utils import generate_random_sample, run_gradient_sim, plot_sun_and_gc, generate_distributed_sample

# %% [markdown]
# ## Read in synthetic populations

# %%
# Load in the data
all_csv_files = [
    f.name
    for f in os.scandir("../../science/synthpop/outputfiles/hge_gums_marshall")
    if f.name.endswith(".csv") and f.name.startswith("hge_gums_marshall_")
]

# Concatenate all files
all_stars = [pd.read_csv(f"../../science/synthpop/outputfiles/hge_gums_marshall/{f}") for f in all_csv_files]
all_stars = pd.concat(all_stars)
print(len(all_stars['l']))
print(all_stars.columns)

# Convert (l,b,dist) to Galactic (R,Z,phi)
all_coords = coordinates.SkyCoord(
    frame="galactic",
    l=all_stars["l"],
    b=all_stars["b"],
    distance=all_stars["Dist"],
    unit=(units.deg, units.deg, units.kpc),
)

all_coords = all_coords.transform_to(coordinates.Galactocentric)
gal_x = all_coords.x / units.kpc
gal_y = all_coords.y / units.kpc
gal_z = all_coords.z / units.kpc
gal_r = np.sqrt(((all_coords.x) ** 2.0) + ((all_coords.y) ** 2.0)) / units.kpc
# Out:
# 5612873
# Index(['pop', 'iMass', 'age', 'Fe/H_initial', 'Mass', 'In_Final_Phase', 'Dist',
#        'l', 'b', 'vr_bc', 'mul', 'mub', 'x', 'y', 'z', 'U', 'V', 'W', 'VR_LSR',
#        'A_Ks', 'logL', 'logTeff', 'logg', 'Fe/H_evolved', 'log_radius',
#        'phase', 'Gaia_G_EDR3', 'Gaia_BP_EDR3', 'Gaia_RP_EDR3', '2MASS_J',
#        '2MASS_H', '2MASS_Ks', 'IRAC_3.6', 'IRAC_4.5'],
#       dtype='str')

# %%
#Define some useful cuts
distance_cut = (all_stars['Dist'] > 6.) #assume we can remove stars within 6 kpc of the sun
hmag_cut = (all_stars['2MASS_H'] < 16) #limit to things visible to use
midplane = (abs(gal_z) < 0.5) #within 0.5 kpc of the midplane

# %% [markdown]
# ## View the data

# %%
#Face-on, top-down, side-on

xr = [-9,15]
yr = [-15,15]
zr = [-2,2]
rr = [0,12]
n_xbins = 40
n_ybins = n_xbins
n_zbins = 20
n_rbins = n_xbins

show = np.logical_and.reduce([distance_cut, hmag_cut])

im_xy, xe, ye, bn = binned_statistic_2d(gal_x[show], gal_y[show], all_stars['l'][show], statistic='count',
                                        range=[xr,yr], bins=[n_xbins,n_ybins])
im_rz, xe, ye, bn = binned_statistic_2d(gal_r[show], gal_z[show], all_stars['l'][show], statistic='count',
                                        range=[rr,zr], bins=[n_rbins,n_zbins])

fig = plt.figure(figsize=(10,4))

ax = plt.subplot(121)
plt.imshow(np.log10(im_xy.T), aspect='auto', origin='lower',
           extent=[min(xr),max(xr),min(yr),max(yr)])
plt.colorbar(label='log(N)')
plt.xlim(xr)
plt.ylim(yr)
plt.xlabel('X [kpc]')
plt.ylabel('Y [kpc]')
plot_sun_and_gc(ax, size=0.5, add_bar=True)

ax = plt.subplot(122)
plt.imshow(np.log10(im_rz.T), aspect='auto', origin='lower',
           extent=[min(rr),max(rr),min(zr),max(zr)])
plt.colorbar(label='log(N)')
plt.xlim(rr)
plt.ylim(zr)
plt.xlabel('R [kpc]')
plt.ylabel('Z [kpc]')

fig.tight_layout()
# Out:
# /var/folders/g9/0lndh9c56xz5yrl_6t6z1wn40000gn/T/ipykernel_32011/2641776493.py:22: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(im_xy.T), aspect='auto', origin='lower',
# /Users/gailzasowski/Library/CloudStorage/Dropbox/Documents/AS-5/hge_targeting/my_utils.py:267: UserWarning: You passed both c and facecolor/facecolors for the markers. c has precedence over facecolor/facecolors. This behavior may change in the future.
#   ax.scatter(
# /var/folders/g9/0lndh9c56xz5yrl_6t6z1wn40000gn/T/ipykernel_32011/2641776493.py:32: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(im_rz.T), aspect='auto', origin='lower',

# %% [markdown]
# ## Generate 4D X/Y/Z/FeH distribution for upsampling later
#
# Only include points brighter than H<16 and farther than d>6 kpc.

# %%
use = np.logical_and.reduce([distance_cut, hmag_cut])
gal_x_rng = [-6,15]
gal_y_rng = [-15,15]
gal_z_rng = [-2,2]
feh_rng = [-1.2,0.6]
n_gal_x_bins = round((gal_x_rng[1]-gal_x_rng[0])/0.5)
n_gal_y_bins = round((gal_y_rng[1]-gal_y_rng[0])/0.5)
n_gal_z_bins = round((gal_z_rng[1]-gal_z_rng[0])/0.25)
n_feh_bins = round((feh_rng[1]-feh_rng[0])/0.05)
data = np.column_stack((gal_x[use], gal_y[use], gal_z[use], all_stars['Fe/H_evolved'][use]))
xyzm_dist, be, bn = binned_statistic_dd(data, gal_x[use], statistic='count', 
                                        bins=(n_gal_x_bins,n_gal_y_bins,n_gal_z_bins,n_feh_bins),
                                        range=[gal_x_rng,gal_y_rng,gal_z_rng,feh_rng])
print(xyzm_dist.shape)
#print(max(xyzm_dist.flatten()))
#_=plt.hist(np.log10(xyzm_dist.flatten()), range=[0,2], bins=40)
#_=plt.hist(all_stars['Fe/H_evolved'][use], bins=40)
plt.imshow(np.log10(xyzm_dist[:,:,round(n_gal_z_bins/2),30]).T, origin='lower')
plt.colorbar()
# Out:
# (42, 60, 16, 36)
# /var/folders/g9/0lndh9c56xz5yrl_6t6z1wn40000gn/T/ipykernel_32011/2854576233.py:18: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(xyzm_dist[:,:,round(n_gal_z_bins/2),30]).T, origin='lower')

# %% [markdown]
# ## Characterize "true" gradient

# %%
#Fit all noiseless data with different |Z|, with and without excluding R<3kpc
z_max_array = [1.0] #, 0.25, 0.5, 0.75, 1.0, 2.0]
r_min_array = [0, 3.5]

for i_z_max, this_z_max in enumerate(z_max_array):
    for i_r_min, this_r_min in enumerate(r_min_array):
        gd = np.logical_and.reduce([distance_cut, hmag_cut, 
                                    abs(gal_z.value) < this_z_max,
                                    gal_r.value > this_r_min])
        n_gd = np.nansum(gd)
        slope, slope_err, median_slopes, median_errs = run_gradient_sim(all_stars[gd], n_gd, dist_uncertainty=0.0, feh_uncertainty=0.0)
        print('|Z_max|={:.2f} kpc, R_min={:.1f} kpc: {:.3f} dex=kpc'.format(this_z_max, this_r_min, median_slopes[0]))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.74it/s]
# |Z_max|=1.00 kpc, R_min=0.0 kpc: -0.055 dex=kpc
#   0%|                                                                                  | 0/1 [00:00<?, ?it/s]/Users/gailzasowski/environments/env_synthpop/.venv/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/gailzasowski/environments/env_synthpop/.venv/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.64it/s]
# |Z_max|=1.00 kpc, R_min=3.5 kpc: -0.063 dex=kpc

# %% [markdown]
# ### Results
#
# - There are enough stars in the midplane that including stars up to |Z|=2 kpc doesn't change the slope, as long as the midplane is well-sampled.
# - If the bulge (with its flatter gradient) is included, the simulation returns a slope of -0.055 dex/kpc.
# - If the bulge is excluded, by requiring $R_{\rm GC} > 3.5$ kpc, the simulation returns a slope of -0.063 dex/kpc.

# %%
true_gradient_all = -0.055
true_gradient_disk = -0.063

# %% [markdown]
# ## Test effects of increasing abundance and distance uncertainties

# %%
#Do matrix of abundance uncertainty x distance uncertainty 

delta_abund_unc = 0.03
abund_uncertainty_array = np.arange(0.01,0.12,delta_abund_unc) #[0.01, 0.05, 0.1] #dex
delta_dist_unc = 0.1
dist_uncertainty_array = np.arange(0.01,0.4,delta_dist_unc) #[0.05, 0.15, 0.3] #fraction of d
slope_array_all = np.full((len(abund_uncertainty_array),len(dist_uncertainty_array)), fill_value=np.nan)
slope_err_array_all = np.full_like(slope_array_all, fill_value=np.nan)
slope_array_disk = np.full_like(slope_array_all, fill_value=np.nan)
slope_err_array_disk = np.full_like(slope_array_all, fill_value=np.nan)

for i_abund_uncertainty, this_abund_uncertainty in enumerate(abund_uncertainty_array):
    for i_dist_uncertainty, this_dist_uncertainty in enumerate(dist_uncertainty_array):
        #All stars
        gd = np.logical_and.reduce([distance_cut, hmag_cut, 
                                    abs(gal_z.value) < 1.0])
        n_gd = np.nansum(gd)
        slope, slope_err, median_slopes, median_errs = run_gradient_sim(all_stars[gd], n_gd, 
                                                                        dist_uncertainty=this_dist_uncertainty, 
                                                                        feh_uncertainty=this_abund_uncertainty,
                                                                        add_noise=True)
        slope_array_all[i_abund_uncertainty,i_dist_uncertainty] = median_slopes[0]
        slope_err_array_all[i_abund_uncertainty,i_dist_uncertainty] = slope_err[0]
        #Disk stars
        gd = np.logical_and.reduce([distance_cut, hmag_cut, 
                                    abs(gal_z.value) < 1.0,
                                    gal_r.value > 3.5])
        n_gd = np.nansum(gd)
        slope, slope_err, median_slopes, median_errs = run_gradient_sim(all_stars[gd], n_gd, 
                                                                        dist_uncertainty=this_dist_uncertainty, 
                                                                        feh_uncertainty=this_abund_uncertainty,
                                                                        add_noise=True)
        slope_array_disk[i_abund_uncertainty,i_dist_uncertainty] = median_slopes[0]
        slope_err_array_disk[i_abund_uncertainty,i_dist_uncertainty] = slope_err[0]
        #print('sig_abund={}, sig_d={}'.format())
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.19it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.95it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.71it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.08it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.16it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.24it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.19it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.82it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.24it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.16it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.74it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.14it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.12it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.26it/s]

# %%
fig = plt.figure(figsize=(12,10))

ax = plt.subplot(321)
plt.imshow(slope_array_all.T-true_gradient_all, origin='lower', aspect='auto',
           extent=[min(abund_uncertainty_array)-delta_abund_unc/2.,max(abund_uncertainty_array)+delta_abund_unc/2.,
                   min(dist_uncertainty_array)-delta_dist_unc/2.,max(dist_uncertainty_array)+delta_dist_unc/2.],
           cmap='PuOr', vmin=-0.08, vmax=0.08)
plt.colorbar(label='(Meas-True) Gradient')
plt.xlabel('Abundance Uncertainty [dex]')
plt.ylabel('Distance Uncertainty [frac]')
plt.title('R>0 kpc')

ax = plt.subplot(322)
plt.imshow(slope_err_array_all.T, origin='lower', aspect='auto',
           extent=[min(abund_uncertainty_array)-delta_abund_unc/2.,max(abund_uncertainty_array)+delta_abund_unc/2.,
                   min(dist_uncertainty_array)-delta_dist_unc/2.,max(dist_uncertainty_array)+delta_dist_unc/2.],
           cmap='Purples')
plt.colorbar(label='Gradient Uncertainty')
plt.xlabel('Abundance Uncertainty [dex]')
plt.ylabel('Distance Uncertainty [frac]')
plt.title('R>0 kpc')

ax = plt.subplot(323)
plt.imshow(slope_array_disk.T-true_gradient_disk, origin='lower', aspect='auto',
           extent=[min(abund_uncertainty_array)-delta_abund_unc/2.,max(abund_uncertainty_array)+delta_abund_unc/2.,
                   min(dist_uncertainty_array)-delta_dist_unc/2.,max(dist_uncertainty_array)+delta_dist_unc/2.],
           cmap='PuOr', vmin=-0.08, vmax=0.08)
plt.colorbar(label='(Meas-True) Gradient')
plt.xlabel('Abundance Uncertainty [dex]')
plt.ylabel('Distance Uncertainty [frac]')
plt.title('R>3.5 kpc')

ax = plt.subplot(324)
plt.imshow(slope_err_array_disk.T, origin='lower', aspect='auto',
           extent=[min(abund_uncertainty_array)-delta_abund_unc/2.,max(abund_uncertainty_array)+delta_abund_unc/2.,
                   min(dist_uncertainty_array)-delta_dist_unc/2.,max(dist_uncertainty_array)+delta_dist_unc/2.],
           cmap='Purples')
plt.colorbar(label='Gradient Uncertainty')
plt.xlabel('Abundance Uncertainty [dex]')
plt.ylabel('Distance Uncertainty [frac]')
plt.title('R>3.5 kpc')

#Direct dependence
abund_unc_colors = mpl.colormaps['Oranges'](np.linspace(0.1, 0.9, len(abund_uncertainty_array)))
dist_unc_colors = mpl.colormaps['Oranges'](np.linspace(0.1, 0.9, len(dist_uncertainty_array)))
gradient_rng = [min([min(slope_array_all.flatten()),min(slope_array_disk.flatten()),true_gradient_all,true_gradient_disk])-0.01,
                max([max(slope_array_all.flatten()),max(slope_array_disk.flatten()),true_gradient_all,true_gradient_disk])+0.01]

ax = plt.subplot(325)
for i_abund_uncertainty, this_abund_uncertainty in enumerate(abund_uncertainty_array):
    plt.plot(dist_uncertainty_array, slope_array_all[i_abund_uncertainty,:], '-o',
             color=abund_unc_colors[i_abund_uncertainty],
             label='Err={:.2f} dex'.format(this_abund_uncertainty))
    plt.plot(dist_uncertainty_array, slope_array_disk[i_abund_uncertainty,:], ':o', 
             color=abund_unc_colors[i_abund_uncertainty])
plt.plot([-50,-50],[-100,-100],'o-', color='k', label='R>0 kpc')
plt.plot([-50,-50],[-100,-100],'o:', color='k', label='R>3.5 kpc')
plt.axhline(true_gradient_all, c="red", lw=3, label="True")
plt.axhspan(true_gradient_all - 0.01, true_gradient_all + 0.01, color="red", alpha=0.1)
plt.axhline(true_gradient_disk, c="green", lw=3, ls=':', label="True")
plt.axhspan(true_gradient_disk - 0.01, true_gradient_disk + 0.01, color="green", alpha=0.1)
plt.legend()
plt.xlim([0,max(dist_uncertainty_array+delta_dist_unc)])
plt.ylim(gradient_rng)
plt.xlabel('Distance Uncertainty [frac]')
plt.ylabel('Gradient [dex/kpc]')

ax = plt.subplot(326)
for i_dist_uncertainty, this_dist_uncertainty in enumerate(dist_uncertainty_array):
    plt.plot(abund_uncertainty_array, slope_array_all[:,i_dist_uncertainty], '-o', 
             color=dist_unc_colors[i_dist_uncertainty],
             label='Err={:.2f} dex'.format(this_dist_uncertainty))
    plt.plot(abund_uncertainty_array, slope_array_disk[:,i_dist_uncertainty], ':o', 
             color=dist_unc_colors[i_dist_uncertainty])
plt.plot([-50,-50],[-100,-100],'o-', color='k', label='R>0 kpc')
plt.plot([-50,-50],[-100,-100],'o:', color='k', label='R>3.5 kpc')
plt.axhline(true_gradient_all, c="red", lw=3, label="True")
plt.axhspan(true_gradient_all - 0.01, true_gradient_all + 0.01, color="red", alpha=0.1)
plt.axhline(true_gradient_disk, c="green", lw=3, ls=':', label="True")
plt.axhspan(true_gradient_disk - 0.01, true_gradient_disk + 0.01, color="green", alpha=0.1)
plt.legend()
plt.xlim([0,max(abund_uncertainty_array+delta_abund_unc)])
plt.ylim(gradient_rng)
plt.xlabel('Abundance Uncertainty [dex]')
plt.ylabel('Gradient [dex/kpc]')

fig.tight_layout()

# %% [markdown]
# ### Results
#
# - Note that since the gradients are <i>negative</i>, a positive number on the left-hand colorbars above (Meas-True Gradient) mean a <i>flatter</i> slope was measured than reality.
# - Abundance uncertainties have little effect in this limited test. (This assumes symmetric, gaussian scatter!)
# - Distance uncertainties matter a lot more than abundance uncertainties. There is always a systematic bias towards flatter slopes, because there are more metal-rich bulge stars to scatter outwards than metal-poorer disk stars to scatter inwards.
# - Keeping distance uncertainties within 10% (everything else held ideal) is needed to keep the shifts within 0.01 dex/kpc.

# %% [markdown]
# ## Test effects of sample size and distribution

# %%
#For 1 (or more?) uncertainty scenarios, test a range of N_stars and distributions

dist_unc0 = 0.15
abund_unc0 = 0.05

n_stars_array = np.logspace(2,5.7,50)
outer_rad_array = [4.0, 8.0, 15.0]
rad_distrib_array = np.array([[90.,10.,0.], #Fraction of stars in R=[0-5/5-8/8+] kpc
                              [75.,25.,0.],
                              [50.,49.,1.],
                              [80.,15.,5.],
                              [20.,70.,10.],
                              [50.,25.,25.]])
rad_distrib_array_actual = np.full_like(rad_distrib_array, fill_value=0.0)
n_rad_distrib = rad_distrib_array.shape[0]
n_radii = rad_distrib_array.shape[1]
slope_array = np.full((len(n_stars_array),n_rad_distrib), fill_value=np.nan)
med_slope_array = np.full_like(slope_array, fill_value=np.nan)
slope_err_array = np.full_like(slope_array, fill_value=np.nan)
n_stars_array_actual = np.full_like(slope_array, fill_value=0.0)

#Downselect all_stars to what we might actually consider targeting, plus other effects
gd = np.logical_and.reduce([distance_cut, 
                            #all_stars['Fe/H_evolved'] > -0.25, #bias against MPer stars
                            #abs(gal_z.value)>0.25, #Uh oh no midplane
                            #np.logical_or.reduce([abs(all_stars['b']) > 2, 
                            #                      np.logical_and.reduce([all_stars['l'] > 10.,
                            #                                             all_stars['l'] < 350.])]), #Uh oh no midplane
                            #np.logical_or.reduce([all_stars['l'] < 10., all_stars['l'] > 180.]), #Uh oh no APO
                            hmag_cut])
n_gd = np.nansum(gd)

#Perturb distances and abundances by their uncertainties
uncertain_dists = [abs(np.random.normal(d, d * dist_unc0)) for d in all_stars["Dist"]]
uncertain_abunds = [np.random.normal(f, abund_unc0) for f in all_stars["Fe/H_evolved"]]

dat = Table()
dat['l'] = all_stars['l']
dat['b'] = all_stars['b']
dat['Dist'] = uncertain_dists
dat['Fe/H_evolved'] = uncertain_abunds

for i_n_stars, this_n_stars in enumerate(n_stars_array):
    for i_rad_distrib in range(n_rad_distrib):
        percents = np.array(rad_distrib_array[i_rad_distrib,:]/100.)
        distributed_stars = generate_distributed_sample(dat[gd], this_n_stars, 
                                                        outer_radii=outer_rad_array, percents=percents, verbose=True)
        n_distributed_stars = len(distributed_stars['l'])
        if n_distributed_stars < this_n_stars:
            n_stars_array_actual[i_n_stars,i_rad_distrib] = n_distributed_stars
        else:
            n_stars_array_actual[i_n_stars,i_rad_distrib] = this_n_stars

        if abs(np.log10(this_n_stars)-4.0) < 0.05:
            for i_radius, this_radius in enumerate(outer_rad_array):
                if i_radius==0:
                    inner_radius = 0.0
                else:
                    inner_radius = outer_rad_array[i_radius-1]
                stars_in_here = np.nansum(np.logical_and.reduce([distributed_stars['gal_r'] > inner_radius,
                                                                 distributed_stars['gal_r'] < this_radius]))
                rad_distrib_array_actual[i_rad_distrib,i_radius] = float(stars_in_here)/float(n_distributed_stars)
            print(n_distributed_stars, percents, rad_distrib_array_actual[i_rad_distrib,:])

        slope, slope_err, median_slopes, median_errs = run_gradient_sim(distributed_stars, this_n_stars, 
                                                                        dist_uncertainty=dist_unc0, feh_uncertainty=abund_unc0, 
                                                                        add_noise=False)
        slope_array[i_n_stars,i_rad_distrib] = slope[0]
        med_slope_array[i_n_stars,i_rad_distrib] = median_slopes[0]
        slope_err_array[i_n_stars,i_rad_distrib] = slope_err[0]
# Out:
# Bin 1: 399915 avail, 90 needed
# Bin 2: 164348 avail, 10 needed
# Bin 3: 36955 avail, 0 needed
#   0%|                                                                                  | 0/1 [00:00<?, ?it/s]/Users/gailzasowski/environments/env_synthpop/.venv/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1213: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/gailzasowski/environments/env_synthpop/.venv/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1997: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 336.92it/s]
# Bin 1: 399915 avail, 75 needed
# Bin 2: 164348 avail, 25 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 303.69it/s]
# Bin 1: 399915 avail, 50 needed
# Bin 2: 164348 avail, 49 needed
# Bin 3: 36955 avail, 1 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 281.06it/s]
# Bin 1: 399915 avail, 80 needed
# Bin 2: 164348 avail, 15 needed
# Bin 3: 36955 avail, 5 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 287.12it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 20 needed
# Bin 2: 164348 avail, 70 needed
# Bin 3: 36955 avail, 10 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 328.19it/s]
# Bin 1: 399915 avail, 50 needed
# Bin 2: 164348 avail, 25 needed
# Bin 3: 36955 avail, 25 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 320.81it/s]
# Bin 1: 399915 avail, 107 needed
# Bin 2: 164348 avail, 11 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 339.07it/s]
# Bin 1: 399915 avail, 89 needed
# Bin 2: 164348 avail, 29 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 37.80it/s]
# Bin 1: 399915 avail, 59 needed
# Bin 2: 164348 avail, 58 needed
# Bin 3: 36955 avail, 1 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 345.04it/s]
# Bin 1: 399915 avail, 95 needed
# Bin 2: 164348 avail, 17 needed
# Bin 3: 36955 avail, 5 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 315.36it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 23 needed
# Bin 2: 164348 avail, 83 needed
# Bin 3: 36955 avail, 11 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 321.75it/s]
# Bin 1: 399915 avail, 59 needed
# Bin 2: 164348 avail, 29 needed
# Bin 3: 36955 avail, 29 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 333.57it/s]
# Bin 1: 399915 avail, 127 needed
# Bin 2: 164348 avail, 14 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 335.81it/s]
# Bin 1: 399915 avail, 106 needed
# Bin 2: 164348 avail, 35 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 326.15it/s]
# Bin 1: 399915 avail, 70 needed
# Bin 2: 164348 avail, 69 needed
# Bin 3: 36955 avail, 1 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 354.58it/s]
# Bin 1: 399915 avail, 113 needed
# Bin 2: 164348 avail, 21 needed
# Bin 3: 36955 avail, 7 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 355.99it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 28 needed
# Bin 2: 164348 avail, 99 needed
# Bin 3: 36955 avail, 14 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 336.14it/s]
# Bin 1: 399915 avail, 70 needed
# Bin 2: 164348 avail, 35 needed
# Bin 3: 36955 avail, 35 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 352.97it/s]
# Bin 1: 399915 avail, 151 needed
# Bin 2: 164348 avail, 16 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 351.64it/s]
# Bin 1: 399915 avail, 126 needed
# Bin 2: 164348 avail, 42 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 321.97it/s]
# Bin 1: 399915 avail, 84 needed
# Bin 2: 164348 avail, 82 needed
# Bin 3: 36955 avail, 1 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 326.48it/s]
# Bin 1: 399915 avail, 134 needed
# Bin 2: 164348 avail, 25 needed
# Bin 3: 36955 avail, 8 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 323.63it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 33 needed
# Bin 2: 164348 avail, 117 needed
# Bin 3: 36955 avail, 16 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 359.84it/s]
# Bin 1: 399915 avail, 84 needed
# Bin 2: 164348 avail, 42 needed
# Bin 3: 36955 avail, 42 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 331.88it/s]
# Bin 1: 399915 avail, 180 needed
# Bin 2: 164348 avail, 20 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 354.76it/s]
# Bin 1: 399915 avail, 150 needed
# Bin 2: 164348 avail, 50 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 326.68it/s]
# Bin 1: 399915 avail, 100 needed
# Bin 2: 164348 avail, 98 needed
# Bin 3: 36955 avail, 2 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 334.31it/s]
# Bin 1: 399915 avail, 160 needed
# Bin 2: 164348 avail, 30 needed
# Bin 3: 36955 avail, 10 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 330.26it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 40 needed
# Bin 2: 164348 avail, 140 needed
# Bin 3: 36955 avail, 20 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 326.76it/s]
# Bin 1: 399915 avail, 100 needed
# Bin 2: 164348 avail, 50 needed
# Bin 3: 36955 avail, 50 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 355.48it/s]
# Bin 1: 399915 avail, 214 needed
# Bin 2: 164348 avail, 23 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 332.99it/s]
# Bin 1: 399915 avail, 178 needed
# Bin 2: 164348 avail, 59 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 327.25it/s]
# Bin 1: 399915 avail, 119 needed
# Bin 2: 164348 avail, 116 needed
# Bin 3: 36955 avail, 2 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 335.12it/s]
# Bin 1: 399915 avail, 190 needed
# Bin 2: 164348 avail, 35 needed
# Bin 3: 36955 avail, 11 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 325.95it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 47 needed
# Bin 2: 164348 avail, 166 needed
# Bin 3: 36955 avail, 23 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 317.15it/s]
# Bin 1: 399915 avail, 119 needed
# Bin 2: 164348 avail, 59 needed
# Bin 3: 36955 avail, 59 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 322.99it/s]
# Bin 1: 399915 avail, 255 needed
# Bin 2: 164348 avail, 28 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 350.40it/s]
# Bin 1: 399915 avail, 212 needed
# Bin 2: 164348 avail, 70 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 324.69it/s]
# Bin 1: 399915 avail, 141 needed
# Bin 2: 164348 avail, 139 needed
# Bin 3: 36955 avail, 2 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 358.18it/s]
# Bin 1: 399915 avail, 227 needed
# Bin 2: 164348 avail, 42 needed
# Bin 3: 36955 avail, 14 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 297.28it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 56 needed
# Bin 2: 164348 avail, 198 needed
# Bin 3: 36955 avail, 28 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 343.51it/s]
# Bin 1: 399915 avail, 141 needed
# Bin 2: 164348 avail, 70 needed
# Bin 3: 36955 avail, 70 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 330.03it/s]
# Bin 1: 399915 avail, 303 needed
# Bin 2: 164348 avail, 33 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 329.07it/s]
# Bin 1: 399915 avail, 253 needed
# Bin 2: 164348 avail, 84 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 348.57it/s]
# Bin 1: 399915 avail, 168 needed
# Bin 2: 164348 avail, 165 needed
# Bin 3: 36955 avail, 3 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 323.81it/s]
# Bin 1: 399915 avail, 270 needed
# Bin 2: 164348 avail, 50 needed
# Bin 3: 36955 avail, 16 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 313.22it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 67 needed
# Bin 2: 164348 avail, 236 needed
# Bin 3: 36955 avail, 33 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 354.73it/s]
# Bin 1: 399915 avail, 168 needed
# Bin 2: 164348 avail, 84 needed
# Bin 3: 36955 avail, 84 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 345.07it/s]
# Bin 1: 399915 avail, 361 needed
# Bin 2: 164348 avail, 40 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 346.75it/s]
# Bin 1: 399915 avail, 301 needed
# Bin 2: 164348 avail, 100 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 324.03it/s]
# Bin 1: 399915 avail, 200 needed
# Bin 2: 164348 avail, 196 needed
# Bin 3: 36955 avail, 4 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 324.16it/s]
# Bin 1: 399915 avail, 321 needed
# Bin 2: 164348 avail, 60 needed
# Bin 3: 36955 avail, 20 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 329.17it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 80 needed
# Bin 2: 164348 avail, 281 needed
# Bin 3: 36955 avail, 40 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 319.98it/s]
# Bin 1: 399915 avail, 200 needed
# Bin 2: 164348 avail, 100 needed
# Bin 3: 36955 avail, 100 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 306.67it/s]
# Bin 1: 399915 avail, 430 needed
# Bin 2: 164348 avail, 47 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 319.69it/s]
# Bin 1: 399915 avail, 358 needed
# Bin 2: 164348 avail, 119 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 310.09it/s]
# Bin 1: 399915 avail, 239 needed
# Bin 2: 164348 avail, 234 needed
# Bin 3: 36955 avail, 4 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 324.26it/s]
# Bin 1: 399915 avail, 382 needed
# Bin 2: 164348 avail, 71 needed
# Bin 3: 36955 avail, 23 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 317.68it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 95 needed
# Bin 2: 164348 avail, 334 needed
# Bin 3: 36955 avail, 47 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 340.36it/s]
# Bin 1: 399915 avail, 239 needed
# Bin 2: 164348 avail, 119 needed
# Bin 3: 36955 avail, 119 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 342.22it/s]
# Bin 1: 399915 avail, 512 needed
# Bin 2: 164348 avail, 56 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 272.25it/s]
# Bin 1: 399915 avail, 426 needed
# Bin 2: 164348 avail, 142 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 275.63it/s]
# Bin 1: 399915 avail, 284 needed
# Bin 2: 164348 avail, 278 needed
# Bin 3: 36955 avail, 5 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 301.86it/s]
# Bin 1: 399915 avail, 455 needed
# Bin 2: 164348 avail, 85 needed
# Bin 3: 36955 avail, 28 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 265.88it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 113 needed
# Bin 2: 164348 avail, 398 needed
# Bin 3: 36955 avail, 56 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 281.04it/s]
# Bin 1: 399915 avail, 284 needed
# Bin 2: 164348 avail, 142 needed
# Bin 3: 36955 avail, 142 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 272.78it/s]
# Bin 1: 399915 avail, 609 needed
# Bin 2: 164348 avail, 67 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 278.56it/s]
# Bin 1: 399915 avail, 507 needed
# Bin 2: 164348 avail, 169 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 293.00it/s]
# Bin 1: 399915 avail, 338 needed
# Bin 2: 164348 avail, 331 needed
# Bin 3: 36955 avail, 6 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 243.18it/s]
# Bin 1: 399915 avail, 541 needed
# Bin 2: 164348 avail, 101 needed
# Bin 3: 36955 avail, 33 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 269.40it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 135 needed
# Bin 2: 164348 avail, 473 needed
# Bin 3: 36955 avail, 67 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 269.18it/s]
# Bin 1: 399915 avail, 338 needed
# Bin 2: 164348 avail, 169 needed
# Bin 3: 36955 avail, 169 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 324.66it/s]
# Bin 1: 399915 avail, 725 needed
# Bin 2: 164348 avail, 80 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 293.86it/s]
# Bin 1: 399915 avail, 604 needed
# Bin 2: 164348 avail, 201 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 257.19it/s]
# Bin 1: 399915 avail, 402 needed
# Bin 2: 164348 avail, 394 needed
# Bin 3: 36955 avail, 8 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 289.60it/s]
# Bin 1: 399915 avail, 644 needed
# Bin 2: 164348 avail, 120 needed
# Bin 3: 36955 avail, 40 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 282.48it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 161 needed
# Bin 2: 164348 avail, 563 needed
# Bin 3: 36955 avail, 80 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 262.11it/s]
# Bin 1: 399915 avail, 402 needed
# Bin 2: 164348 avail, 201 needed
# Bin 3: 36955 avail, 201 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 288.94it/s]
# Bin 1: 399915 avail, 862 needed
# Bin 2: 164348 avail, 95 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 247.58it/s]
# Bin 1: 399915 avail, 718 needed
# Bin 2: 164348 avail, 239 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 255.36it/s]
# Bin 1: 399915 avail, 479 needed
# Bin 2: 164348 avail, 469 needed
# Bin 3: 36955 avail, 9 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 277.46it/s]
# Bin 1: 399915 avail, 766 needed
# Bin 2: 164348 avail, 143 needed
# Bin 3: 36955 avail, 47 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 278.49it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 191 needed
# Bin 2: 164348 avail, 671 needed
# Bin 3: 36955 avail, 95 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 270.29it/s]
# Bin 1: 399915 avail, 479 needed
# Bin 2: 164348 avail, 239 needed
# Bin 3: 36955 avail, 239 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 282.48it/s]
# Bin 1: 399915 avail, 1026 needed
# Bin 2: 164348 avail, 114 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 245.81it/s]
# Bin 1: 399915 avail, 855 needed
# Bin 2: 164348 avail, 285 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 289.54it/s]
# Bin 1: 399915 avail, 570 needed
# Bin 2: 164348 avail, 558 needed
# Bin 3: 36955 avail, 11 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 304.13it/s]
# Bin 1: 399915 avail, 912 needed
# Bin 2: 164348 avail, 171 needed
# Bin 3: 36955 avail, 57 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.45it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 228 needed
# Bin 2: 164348 avail, 798 needed
# Bin 3: 36955 avail, 114 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 272.32it/s]
# Bin 1: 399915 avail, 570 needed
# Bin 2: 164348 avail, 285 needed
# Bin 3: 36955 avail, 285 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 278.95it/s]
# Bin 1: 399915 avail, 1221 needed
# Bin 2: 164348 avail, 135 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 246.56it/s]
# Bin 1: 399915 avail, 1017 needed
# Bin 2: 164348 avail, 339 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 236.02it/s]
# Bin 1: 399915 avail, 678 needed
# Bin 2: 164348 avail, 665 needed
# Bin 3: 36955 avail, 13 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 245.24it/s]
# Bin 1: 399915 avail, 1085 needed
# Bin 2: 164348 avail, 203 needed
# Bin 3: 36955 avail, 67 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 280.50it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 271 needed
# Bin 2: 164348 avail, 950 needed
# Bin 3: 36955 avail, 135 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 255.16it/s]
# Bin 1: 399915 avail, 678 needed
# Bin 2: 164348 avail, 339 needed
# Bin 3: 36955 avail, 339 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 259.00it/s]
# Bin 1: 399915 avail, 1453 needed
# Bin 2: 164348 avail, 161 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 250.12it/s]
# Bin 1: 399915 avail, 1211 needed
# Bin 2: 164348 avail, 403 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 245.90it/s]
# Bin 1: 399915 avail, 807 needed
# Bin 2: 164348 avail, 791 needed
# Bin 3: 36955 avail, 16 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 234.36it/s]
# Bin 1: 399915 avail, 1291 needed
# Bin 2: 164348 avail, 242 needed
# Bin 3: 36955 avail, 80 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 274.33it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 322 needed
# Bin 2: 164348 avail, 1130 needed
# Bin 3: 36955 avail, 161 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 258.54it/s]
# Bin 1: 399915 avail, 807 needed
# Bin 2: 164348 avail, 403 needed
# Bin 3: 36955 avail, 403 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 241.84it/s]
# Bin 1: 399915 avail, 1729 needed
# Bin 2: 164348 avail, 192 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 237.83it/s]
# Bin 1: 399915 avail, 1441 needed
# Bin 2: 164348 avail, 480 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 220.31it/s]
# Bin 1: 399915 avail, 960 needed
# Bin 2: 164348 avail, 941 needed
# Bin 3: 36955 avail, 19 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 235.34it/s]
# Bin 1: 399915 avail, 1537 needed
# Bin 2: 164348 avail, 288 needed
# Bin 3: 36955 avail, 96 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 246.36it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 384 needed
# Bin 2: 164348 avail, 1345 needed
# Bin 3: 36955 avail, 192 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 252.20it/s]
# Bin 1: 399915 avail, 960 needed
# Bin 2: 164348 avail, 480 needed
# Bin 3: 36955 avail, 480 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 267.44it/s]
# Bin 1: 399915 avail, 2057 needed
# Bin 2: 164348 avail, 228 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 251.76it/s]
# Bin 1: 399915 avail, 1714 needed
# Bin 2: 164348 avail, 571 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 225.27it/s]
# Bin 1: 399915 avail, 1143 needed
# Bin 2: 164348 avail, 1120 needed
# Bin 3: 36955 avail, 22 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 237.48it/s]
# Bin 1: 399915 avail, 1829 needed
# Bin 2: 164348 avail, 342 needed
# Bin 3: 36955 avail, 114 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 222.27it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 457 needed
# Bin 2: 164348 avail, 1600 needed
# Bin 3: 36955 avail, 228 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 238.31it/s]
# Bin 1: 399915 avail, 1143 needed
# Bin 2: 164348 avail, 571 needed
# Bin 3: 36955 avail, 571 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 226.39it/s]
# Bin 1: 399915 avail, 2448 needed
# Bin 2: 164348 avail, 272 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 220.51it/s]
# Bin 1: 399915 avail, 2040 needed
# Bin 2: 164348 avail, 680 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 207.04it/s]
# Bin 1: 399915 avail, 1360 needed
# Bin 2: 164348 avail, 1333 needed
# Bin 3: 36955 avail, 27 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 216.45it/s]
# Bin 1: 399915 avail, 2176 needed
# Bin 2: 164348 avail, 408 needed
# Bin 3: 36955 avail, 136 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 224.11it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 544 needed
# Bin 2: 164348 avail, 1904 needed
# Bin 3: 36955 avail, 272 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 210.44it/s]
# Bin 1: 399915 avail, 1360 needed
# Bin 2: 164348 avail, 680 needed
# Bin 3: 36955 avail, 680 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 218.92it/s]
# Bin 1: 399915 avail, 2913 needed
# Bin 2: 164348 avail, 323 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 220.51it/s]
# Bin 1: 399915 avail, 2428 needed
# Bin 2: 164348 avail, 809 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 209.56it/s]
# Bin 1: 399915 avail, 1618 needed
# Bin 2: 164348 avail, 1586 needed
# Bin 3: 36955 avail, 32 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 216.40it/s]
# Bin 1: 399915 avail, 2589 needed
# Bin 2: 164348 avail, 485 needed
# Bin 3: 36955 avail, 161 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 208.37it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 647 needed
# Bin 2: 164348 avail, 2266 needed
# Bin 3: 36955 avail, 323 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 207.68it/s]
# Bin 1: 399915 avail, 1618 needed
# Bin 2: 164348 avail, 809 needed
# Bin 3: 36955 avail, 809 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 214.14it/s]
# Bin 1: 399915 avail, 3467 needed
# Bin 2: 164348 avail, 385 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 192.45it/s]
# Bin 1: 399915 avail, 2889 needed
# Bin 2: 164348 avail, 963 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 201.05it/s]
# Bin 1: 399915 avail, 1926 needed
# Bin 2: 164348 avail, 1887 needed
# Bin 3: 36955 avail, 38 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 207.30it/s]
# Bin 1: 399915 avail, 3081 needed
# Bin 2: 164348 avail, 577 needed
# Bin 3: 36955 avail, 192 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 223.10it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 770 needed
# Bin 2: 164348 avail, 2696 needed
# Bin 3: 36955 avail, 385 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 209.24it/s]
# Bin 1: 399915 avail, 1926 needed
# Bin 2: 164348 avail, 963 needed
# Bin 3: 36955 avail, 963 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 204.87it/s]
# Bin 1: 399915 avail, 4125 needed
# Bin 2: 164348 avail, 458 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 201.61it/s]
# Bin 1: 399915 avail, 3437 needed
# Bin 2: 164348 avail, 1145 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 200.67it/s]
# Bin 1: 399915 avail, 2291 needed
# Bin 2: 164348 avail, 2246 needed
# Bin 3: 36955 avail, 45 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 198.92it/s]
# Bin 1: 399915 avail, 3667 needed
# Bin 2: 164348 avail, 687 needed
# Bin 3: 36955 avail, 229 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 214.41it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 916 needed
# Bin 2: 164348 avail, 3208 needed
# Bin 3: 36955 avail, 458 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 192.05it/s]
# Bin 1: 399915 avail, 2291 needed
# Bin 2: 164348 avail, 1145 needed
# Bin 3: 36955 avail, 1145 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 199.41it/s]
# Bin 1: 399915 avail, 4908 needed
# Bin 2: 164348 avail, 545 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 181.89it/s]
# Bin 1: 399915 avail, 4090 needed
# Bin 2: 164348 avail, 1363 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 184.68it/s]
# Bin 1: 399915 avail, 2727 needed
# Bin 2: 164348 avail, 2672 needed
# Bin 3: 36955 avail, 54 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 184.50it/s]
# Bin 1: 399915 avail, 4363 needed
# Bin 2: 164348 avail, 818 needed
# Bin 3: 36955 avail, 272 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 200.41it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 1090 needed
# Bin 2: 164348 avail, 3817 needed
# Bin 3: 36955 avail, 545 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 199.80it/s]
# Bin 1: 399915 avail, 2727 needed
# Bin 2: 164348 avail, 1363 needed
# Bin 3: 36955 avail, 1363 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 199.43it/s]
# Bin 1: 399915 avail, 5841 needed
# Bin 2: 164348 avail, 649 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 165.30it/s]
# Bin 1: 399915 avail, 4867 needed
# Bin 2: 164348 avail, 1622 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 177.81it/s]
# Bin 1: 399915 avail, 3245 needed
# Bin 2: 164348 avail, 3180 needed
# Bin 3: 36955 avail, 64 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 176.71it/s]
# Bin 1: 399915 avail, 5192 needed
# Bin 2: 164348 avail, 973 needed
# Bin 3: 36955 avail, 324 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 181.12it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 1298 needed
# Bin 2: 164348 avail, 4543 needed
# Bin 3: 36955 avail, 649 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 189.15it/s]
# Bin 1: 399915 avail, 3245 needed
# Bin 2: 164348 avail, 1622 needed
# Bin 3: 36955 avail, 1622 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 181.52it/s]
# Bin 1: 399915 avail, 6950 needed
# Bin 2: 164348 avail, 772 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 172.83it/s]
# Bin 1: 399915 avail, 5791 needed
# Bin 2: 164348 avail, 1930 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 165.89it/s]
# Bin 1: 399915 avail, 3861 needed
# Bin 2: 164348 avail, 3784 needed
# Bin 3: 36955 avail, 77 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 166.58it/s]
# Bin 1: 399915 avail, 6177 needed
# Bin 2: 164348 avail, 1158 needed
# Bin 3: 36955 avail, 386 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 167.76it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 1544 needed
# Bin 2: 164348 avail, 5405 needed
# Bin 3: 36955 avail, 772 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 165.86it/s]
# Bin 1: 399915 avail, 3861 needed
# Bin 2: 164348 avail, 1930 needed
# Bin 3: 36955 avail, 1930 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 163.27it/s]
# Bin 1: 399915 avail, 8270 needed
# Bin 2: 164348 avail, 918 needed
# Bin 3: 36955 avail, 0 needed
# 9188 [0.9 0.1 0. ] [0.90008707 0.09991293 0.        ]
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 159.59it/s]
# Bin 1: 399915 avail, 6891 needed
# Bin 2: 164348 avail, 2297 needed
# Bin 3: 36955 avail, 0 needed
# 9188 [0.75 0.25 0.  ] [0.75 0.25 0.  ]
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 157.31it/s]
# Bin 1: 399915 avail, 4594 needed
# Bin 2: 164348 avail, 4502 needed
# Bin 3: 36955 avail, 91 needed
# 9187 [0.5  0.49 0.01] [0.50005442 0.49004027 0.0099053 ]
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 164.80it/s]
# Bin 1: 399915 avail, 7351 needed
# Bin 2: 164348 avail, 1378 needed
# Bin 3: 36955 avail, 459 needed
# 9188 [0.8  0.15 0.05] [0.8000653  0.14997823 0.04995646]
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 157.65it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 1837 needed
# Bin 2: 164348 avail, 6432 needed
# Bin 3: 36955 avail, 918 needed
# 9187 [0.2 0.7 0.1] [0.19995646 0.70011973 0.09992381]
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 156.13it/s]
# Bin 1: 399915 avail, 4594 needed
# Bin 2: 164348 avail, 2297 needed
# Bin 3: 36955 avail, 2297 needed
# 9188 [0.5  0.25 0.25] [0.5  0.25 0.25]
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 156.06it/s]
# Bin 1: 399915 avail, 9840 needed
# Bin 2: 164348 avail, 1093 needed
# Bin 3: 36955 avail, 0 needed
# 10933 [0.9 0.1 0. ] [0.90002744 0.09997256 0.        ]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 83.24it/s]
# Bin 1: 399915 avail, 8200 needed
# Bin 2: 164348 avail, 2733 needed
# Bin 3: 36955 avail, 0 needed
# 10933 [0.75 0.25 0.  ] [0.75002287 0.24997713 0.        ]
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 115.34it/s]
# Bin 1: 399915 avail, 5466 needed
# Bin 2: 164348 avail, 5357 needed
# Bin 3: 36955 avail, 109 needed
# 10932 [0.5  0.49 0.01] [0.5        0.49002927 0.00997073]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 59.33it/s]
# Bin 1: 399915 avail, 8747 needed
# Bin 2: 164348 avail, 1640 needed
# Bin 3: 36955 avail, 546 needed
# 10933 [0.8  0.15 0.05] [0.80005488 0.15000457 0.04994055]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 41.13it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 2186 needed
# Bin 2: 164348 avail, 7653 needed
# Bin 3: 36955 avail, 1093 needed
# 10932 [0.2 0.7 0.1] [0.19996341 0.70005488 0.09998171]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 43.66it/s]
# Bin 1: 399915 avail, 5466 needed
# Bin 2: 164348 avail, 2733 needed
# Bin 3: 36955 avail, 2733 needed
# 10932 [0.5  0.25 0.25] [0.5  0.25 0.25]
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 56.62it/s]
# Bin 1: 399915 avail, 11709 needed
# Bin 2: 164348 avail, 1301 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 75.67it/s]
# Bin 1: 399915 avail, 9757 needed
# Bin 2: 164348 avail, 3252 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 71.00it/s]
# Bin 1: 399915 avail, 6505 needed
# Bin 2: 164348 avail, 6375 needed
# Bin 3: 36955 avail, 130 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 88.02it/s]
# Bin 1: 399915 avail, 10408 needed
# Bin 2: 164348 avail, 1951 needed
# Bin 3: 36955 avail, 650 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 65.43it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 2602 needed
# Bin 2: 164348 avail, 9107 needed
# Bin 3: 36955 avail, 1301 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 75.23it/s]
# Bin 1: 399915 avail, 6505 needed
# Bin 2: 164348 avail, 3252 needed
# Bin 3: 36955 avail, 3252 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 87.91it/s]
# Bin 1: 399915 avail, 13932 needed
# Bin 2: 164348 avail, 1548 needed
# Bin 3: 36955 avail, 0 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 114.73it/s]
# Bin 1: 399915 avail, 11610 needed
# Bin 2: 164348 avail, 3870 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 44.92it/s]
# Bin 1: 399915 avail, 7740 needed
# Bin 2: 164348 avail, 7585 needed
# Bin 3: 36955 avail, 154 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 42.52it/s]
# Bin 1: 399915 avail, 12384 needed
# Bin 2: 164348 avail, 2322 needed
# Bin 3: 36955 avail, 774 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 62.98it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 3096 needed
# Bin 2: 164348 avail, 10836 needed
# Bin 3: 36955 avail, 1548 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 81.79it/s]
# Bin 1: 399915 avail, 7740 needed
# Bin 2: 164348 avail, 3870 needed
# Bin 3: 36955 avail, 3870 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 36.96it/s]
# Bin 1: 399915 avail, 16578 needed
# Bin 2: 164348 avail, 1842 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 54.86it/s]
# Bin 1: 399915 avail, 13815 needed
# Bin 2: 164348 avail, 4605 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 46.93it/s]
# Bin 1: 399915 avail, 9210 needed
# Bin 2: 164348 avail, 9026 needed
# Bin 3: 36955 avail, 184 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 49.55it/s]
# Bin 1: 399915 avail, 14736 needed
# Bin 2: 164348 avail, 2763 needed
# Bin 3: 36955 avail, 921 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 69.34it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 3684 needed
# Bin 2: 164348 avail, 12894 needed
# Bin 3: 36955 avail, 1842 needed
# 100%|█████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 100.59it/s]
# Bin 1: 399915 avail, 9210 needed
# Bin 2: 164348 avail, 4605 needed
# Bin 3: 36955 avail, 4605 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 66.37it/s]
# Bin 1: 399915 avail, 19726 needed
# Bin 2: 164348 avail, 2191 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 42.19it/s]
# Bin 1: 399915 avail, 16439 needed
# Bin 2: 164348 avail, 5479 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 62.35it/s]
# Bin 1: 399915 avail, 10959 needed
# Bin 2: 164348 avail, 10740 needed
# Bin 3: 36955 avail, 219 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 36.76it/s]
# Bin 1: 399915 avail, 17535 needed
# Bin 2: 164348 avail, 3287 needed
# Bin 3: 36955 avail, 1095 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 58.68it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 4383 needed
# Bin 2: 164348 avail, 15343 needed
# Bin 3: 36955 avail, 2191 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 93.85it/s]
# Bin 1: 399915 avail, 10959 needed
# Bin 2: 164348 avail, 5479 needed
# Bin 3: 36955 avail, 5479 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 47.61it/s]
# Bin 1: 399915 avail, 23473 needed
# Bin 2: 164348 avail, 2608 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 46.68it/s]
# Bin 1: 399915 avail, 19560 needed
# Bin 2: 164348 avail, 6520 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 42.67it/s]
# Bin 1: 399915 avail, 13040 needed
# Bin 2: 164348 avail, 12779 needed
# Bin 3: 36955 avail, 260 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 69.06it/s]
# Bin 1: 399915 avail, 20864 needed
# Bin 2: 164348 avail, 3912 needed
# Bin 3: 36955 avail, 1304 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 72.99it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 5216 needed
# Bin 2: 164348 avail, 18256 needed
# Bin 3: 36955 avail, 2608 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 47.44it/s]
# Bin 1: 399915 avail, 13040 needed
# Bin 2: 164348 avail, 6520 needed
# Bin 3: 36955 avail, 6520 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 38.65it/s]
# Bin 1: 399915 avail, 27930 needed
# Bin 2: 164348 avail, 3103 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 37.49it/s]
# Bin 1: 399915 avail, 23275 needed
# Bin 2: 164348 avail, 7758 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 37.13it/s]
# Bin 1: 399915 avail, 15516 needed
# Bin 2: 164348 avail, 15206 needed
# Bin 3: 36955 avail, 310 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 64.56it/s]
# Bin 1: 399915 avail, 24827 needed
# Bin 2: 164348 avail, 4655 needed
# Bin 3: 36955 avail, 1551 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 64.59it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 6206 needed
# Bin 2: 164348 avail, 21723 needed
# Bin 3: 36955 avail, 3103 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 50.68it/s]
# Bin 1: 399915 avail, 15516 needed
# Bin 2: 164348 avail, 7758 needed
# Bin 3: 36955 avail, 7758 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 34.60it/s]
# Bin 1: 399915 avail, 33234 needed
# Bin 2: 164348 avail, 3692 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 35.87it/s]
# Bin 1: 399915 avail, 27695 needed
# Bin 2: 164348 avail, 9231 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 29.63it/s]
# Bin 1: 399915 avail, 18463 needed
# Bin 2: 164348 avail, 18094 needed
# Bin 3: 36955 avail, 369 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 36.25it/s]
# Bin 1: 399915 avail, 29541 needed
# Bin 2: 164348 avail, 5539 needed
# Bin 3: 36955 avail, 1846 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 33.79it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 7385 needed
# Bin 2: 164348 avail, 25849 needed
# Bin 3: 36955 avail, 3692 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 48.28it/s]
# Bin 1: 399915 avail, 18463 needed
# Bin 2: 164348 avail, 9231 needed
# Bin 3: 36955 avail, 9231 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 63.10it/s]
# Bin 1: 399915 avail, 39545 needed
# Bin 2: 164348 avail, 4393 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 30.82it/s]
# Bin 1: 399915 avail, 32954 needed
# Bin 2: 164348 avail, 10984 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 56.60it/s]
# Bin 1: 399915 avail, 21969 needed
# Bin 2: 164348 avail, 21530 needed
# Bin 3: 36955 avail, 439 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 29.86it/s]
# Bin 1: 399915 avail, 35151 needed
# Bin 2: 164348 avail, 6590 needed
# Bin 3: 36955 avail, 2196 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 26.79it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 8787 needed
# Bin 2: 164348 avail, 30757 needed
# Bin 3: 36955 avail, 4393 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 39.06it/s]
# Bin 1: 399915 avail, 21969 needed
# Bin 2: 164348 avail, 10984 needed
# Bin 3: 36955 avail, 10984 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 43.54it/s]
# Bin 1: 399915 avail, 47055 needed
# Bin 2: 164348 avail, 5228 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 21.86it/s]
# Bin 1: 399915 avail, 39212 needed
# Bin 2: 164348 avail, 13070 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 37.41it/s]
# Bin 1: 399915 avail, 26141 needed
# Bin 2: 164348 avail, 25619 needed
# Bin 3: 36955 avail, 522 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 36.29it/s]
# Bin 1: 399915 avail, 41827 needed
# Bin 2: 164348 avail, 7842 needed
# Bin 3: 36955 avail, 2614 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 48.49it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 10456 needed
# Bin 2: 164348 avail, 36598 needed
# Bin 3: 36955 avail, 5228 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 23.51it/s]
# Bin 1: 399915 avail, 26141 needed
# Bin 2: 164348 avail, 13070 needed
# Bin 3: 36955 avail, 13070 needed
# ...
# Bin 1: 399915 avail, 12442 needed
# Bin 2: 164348 avail, 43548 needed
# Bin 3: 36955 avail, 6221 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 23.33it/s]
# Bin 1: 399915 avail, 31106 needed
# Bin 2: 164348 avail, 15553 needed
# Bin 3: 36955 avail, 15553 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 30.44it/s]
# Bin 1: 399915 avail, 66623 needed
# Bin 2: 164348 avail, 7402 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.94it/s]
# Bin 1: 399915 avail, 55519 needed
# Bin 2: 164348 avail, 18506 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.99it/s]
# Bin 1: 399915 avail, 37013 needed
# Bin 2: 164348 avail, 36273 needed
# Bin 3: 36955 avail, 740 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 29.69it/s]
# Bin 1: 399915 avail, 59221 needed
# Bin 2: 164348 avail, 11103 needed
# Bin 3: 36955 avail, 3701 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 34.96it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 14805 needed
# Bin 2: 164348 avail, 51818 needed
# Bin 3: 36955 avail, 7402 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 35.67it/s]
# Bin 1: 399915 avail, 37013 needed
# Bin 2: 164348 avail, 18506 needed
# Bin 3: 36955 avail, 18506 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.14it/s]
# Bin 1: 399915 avail, 79275 needed
# Bin 2: 164348 avail, 8808 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 21.78it/s]
# Bin 1: 399915 avail, 66063 needed
# Bin 2: 164348 avail, 22021 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.64it/s]
# Bin 1: 399915 avail, 44042 needed
# Bin 2: 164348 avail, 43161 needed
# Bin 3: 36955 avail, 880 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 25.14it/s]
# Bin 1: 399915 avail, 70467 needed
# Bin 2: 164348 avail, 13212 needed
# Bin 3: 36955 avail, 4404 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 15.69it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 17616 needed
# Bin 2: 164348 avail, 61658 needed
# Bin 3: 36955 avail, 8808 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 17.92it/s]
# Bin 1: 399915 avail, 44042 needed
# Bin 2: 164348 avail, 22021 needed
# Bin 3: 36955 avail, 22021 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 26.03it/s]
# Bin 1: 399915 avail, 94330 needed
# Bin 2: 164348 avail, 10481 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 22.10it/s]
# Bin 1: 399915 avail, 78608 needed
# Bin 2: 164348 avail, 26202 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 25.55it/s]
# Bin 1: 399915 avail, 52405 needed
# Bin 2: 164348 avail, 51357 needed
# Bin 3: 36955 avail, 1048 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 24.57it/s]
# Bin 1: 399915 avail, 83849 needed
# Bin 2: 164348 avail, 15721 needed
# Bin 3: 36955 avail, 5240 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 14.25it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 20962 needed
# Bin 2: 164348 avail, 73367 needed
# Bin 3: 36955 avail, 10481 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.40it/s]
# Bin 1: 399915 avail, 52405 needed
# Bin 2: 164348 avail, 26202 needed
# Bin 3: 36955 avail, 26202 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 21.63it/s]
# Bin 1: 399915 avail, 112243 needed
# Bin 2: 164348 avail, 12471 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 20.49it/s]
# Bin 1: 399915 avail, 93536 needed
# Bin 2: 164348 avail, 31178 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.94it/s]
# Bin 1: 399915 avail, 62357 needed
# Bin 2: 164348 avail, 61110 needed
# Bin 3: 36955 avail, 1247 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.45it/s]
# Bin 1: 399915 avail, 99771 needed
# Bin 2: 164348 avail, 18707 needed
# Bin 3: 36955 avail, 6235 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.99it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 24942 needed
# Bin 2: 164348 avail, 87300 needed
# Bin 3: 36955 avail, 12471 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.44it/s]
# Bin 1: 399915 avail, 62357 needed
# Bin 2: 164348 avail, 31178 needed
# Bin 3: 36955 avail, 31178 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 19.55it/s]
# Bin 1: 399915 avail, 133558 needed
# Bin 2: 164348 avail, 14839 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.33it/s]
# Bin 1: 399915 avail, 111298 needed
# Bin 2: 164348 avail, 37099 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.79it/s]
# Bin 1: 399915 avail, 74199 needed
# Bin 2: 164348 avail, 72715 needed
# Bin 3: 36955 avail, 1483 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 18.07it/s]
# Bin 1: 399915 avail, 118718 needed
# Bin 2: 164348 avail, 22259 needed
# Bin 3: 36955 avail, 7419 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.08it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 29679 needed
# Bin 2: 164348 avail, 103878 needed
# Bin 3: 36955 avail, 14839 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.47it/s]
# Bin 1: 399915 avail, 74199 needed
# Bin 2: 164348 avail, 37099 needed
# Bin 3: 36955 avail, 37099 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 16.63it/s]
# Bin 1: 399915 avail, 158920 needed
# Bin 2: 164348 avail, 17657 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.44it/s]
# Bin 1: 399915 avail, 132434 needed
# Bin 2: 164348 avail, 44144 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.96it/s]
# Bin 1: 399915 avail, 88289 needed
# Bin 2: 164348 avail, 86523 needed
# Bin 3: 36955 avail, 1765 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.94it/s]
# Bin 1: 399915 avail, 141263 needed
# Bin 2: 164348 avail, 26486 needed
# Bin 3: 36955 avail, 8828 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.57it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 35315 needed
# Bin 2: 164348 avail, 123605 needed
# Bin 3: 36955 avail, 17657 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.15it/s]
# Bin 1: 399915 avail, 88289 needed
# Bin 2: 164348 avail, 44144 needed
# Bin 3: 36955 avail, 44144 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.67it/s]
# Bin 1: 399915 avail, 189099 needed
# Bin 2: 164348 avail, 21011 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 12.98it/s]
# Bin 1: 399915 avail, 157583 needed
# Bin 2: 164348 avail, 52527 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.41it/s]
# Bin 1: 399915 avail, 105055 needed
# Bin 2: 164348 avail, 102954 needed
# Bin 3: 36955 avail, 2101 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.37it/s]
# Bin 1: 399915 avail, 168088 needed
# Bin 2: 164348 avail, 31516 needed
# Bin 3: 36955 avail, 10505 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.56it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 42022 needed
# Bin 2: 164348 avail, 147077 needed
# Bin 3: 36955 avail, 21011 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.80it/s]
# Bin 1: 399915 avail, 105055 needed
# Bin 2: 164348 avail, 52527 needed
# Bin 3: 36955 avail, 52527 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 13.07it/s]
# Bin 1: 399915 avail, 225009 needed
# Bin 2: 164348 avail, 25001 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.88it/s]
# Bin 1: 399915 avail, 187508 needed
# Bin 2: 164348 avail, 62502 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.60it/s]
# Bin 1: 399915 avail, 125005 needed
# Bin 2: 164348 avail, 122505 needed
# Bin 3: 36955 avail, 2500 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.64it/s]
# Bin 1: 399915 avail, 200008 needed
# Bin 2: 164348 avail, 37501 needed
# Bin 3: 36955 avail, 12500 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.37it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 50002 needed
# Bin 2: 164348 avail, 175007 needed
# Bin 3: 36955 avail, 25001 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 10.45it/s]
# Bin 1: 399915 avail, 125005 needed
# Bin 2: 164348 avail, 62502 needed
# Bin 3: 36955 avail, 62502 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.00it/s]
# Bin 1: 399915 avail, 267739 needed
# Bin 2: 164348 avail, 29748 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.26it/s]
# Bin 1: 399915 avail, 223115 needed
# Bin 2: 164348 avail, 74371 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.88it/s]
# Bin 1: 399915 avail, 148743 needed
# Bin 2: 164348 avail, 145769 needed
# Bin 3: 36955 avail, 2974 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.36it/s]
# Bin 1: 399915 avail, 237990 needed
# Bin 2: 164348 avail, 44623 needed
# Bin 3: 36955 avail, 14874 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.34it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 59497 needed
# Bin 2: 164348 avail, 208241 needed
# Bin 3: 36955 avail, 29748 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 11.24it/s]
# Bin 1: 399915 avail, 148743 needed
# Bin 2: 164348 avail, 74371 needed
# Bin 3: 36955 avail, 74371 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.71it/s]
# Bin 1: 399915 avail, 318582 needed
# Bin 2: 164348 avail, 35398 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.52it/s]
# Bin 1: 399915 avail, 265485 needed
# Bin 2: 164348 avail, 88495 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.41it/s]
# Bin 1: 399915 avail, 176990 needed
# Bin 2: 164348 avail, 173450 needed
# Bin 3: 36955 avail, 3539 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.83it/s]
# Bin 1: 399915 avail, 283184 needed
# Bin 2: 164348 avail, 53097 needed
# Bin 3: 36955 avail, 17699 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.92it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 70796 needed
# Bin 2: 164348 avail, 247786 needed
# Bin 3: 36955 avail, 35398 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.58it/s]
# Bin 1: 399915 avail, 176990 needed
# Bin 2: 164348 avail, 88495 needed
# Bin 3: 36955 avail, 88495 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.37it/s]
# Bin 1: 399915 avail, 379081 needed
# Bin 2: 164348 avail, 42120 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.09it/s]
# Bin 1: 399915 avail, 315901 needed
# Bin 2: 164348 avail, 105300 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.97it/s]
# Bin 1: 399915 avail, 210600 needed
# Bin 2: 164348 avail, 206388 needed
# Bin 3: 36955 avail, 4212 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.81it/s]
# Bin 1: 399915 avail, 336961 needed
# Bin 2: 164348 avail, 63180 needed
# Bin 3: 36955 avail, 21060 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.25it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 84240 needed
# Bin 2: 164348 avail, 294840 needed
# Bin 3: 36955 avail, 42120 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.54it/s]
# Bin 1: 399915 avail, 210600 needed
# Bin 2: 164348 avail, 105300 needed
# Bin 3: 36955 avail, 105300 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.17it/s]
# Bin 1: 399915 avail, 451068 needed
# Bin 2: 164348 avail, 50118 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.32it/s]
# Bin 1: 399915 avail, 375890 needed
# Bin 2: 164348 avail, 125296 needed
# Bin 3: 36955 avail, 0 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.96it/s]
# Bin 1: 399915 avail, 250593 needed
# Bin 2: 164348 avail, 245581 needed
# Bin 3: 36955 avail, 5011 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.93it/s]
# Bin 1: 399915 avail, 400949 needed
# Bin 2: 164348 avail, 75178 needed
# Bin 3: 36955 avail, 25059 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.72it/s]
# Warning: percents do not add to 1.0
# Bin 1: 399915 avail, 100237 needed
# Bin 2: 164348 avail, 350831 needed
# Bin 3: 36955 avail, 50118 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.98it/s]
# Bin 1: 399915 avail, 250593 needed
# Bin 2: 164348 avail, 125296 needed
# Bin 3: 36955 avail, 125296 needed
# 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.04it/s]

# %%
fig = plt.figure(figsize=(12,6))

gradient_rng = [min([true_gradient_all,true_gradient_disk])-0.04,
                max([true_gradient_all,true_gradient_disk])+0.04]
rad_distrib_colors = mpl.colormaps['plasma'](np.linspace(0.1, 0.9, n_rad_distrib))

ax = plt.subplot(111)
for i_rad_distrib in range(n_rad_distrib):
    p1,p2,p3 = np.array(rad_distrib_array_actual[i_rad_distrib,0:3])
    #plt.plot(np.log10(n_stars_array), slope_array[:,i_rad_distrib], 'o-', 
    plt.plot(np.log10(n_stars_array_actual[:,i_rad_distrib]), med_slope_array[:,i_rad_distrib], 'o-',
             color=rad_distrib_colors[i_rad_distrib], zorder=2, 
             label='{:.2f}/{:.2f}/{:.2f}'.format(p1,p2,p3))
    #plt.errorbar(np.log10(n_stars_array), slope_array[:,i_rad_distrib], marker='.', color='w',
    #             yerr=slope_err_array[:,3], ecolor='gray', capsize=0, ls='', zorder=1)
    plt.fill_between(np.log10(n_stars_array), med_slope_array[:,i_rad_distrib],
                     y2=med_slope_array[:,i_rad_distrib]+slope_err_array[:,3],
                     color=rad_distrib_colors[i_rad_distrib], alpha=0.2)
    plt.fill_between(np.log10(n_stars_array), med_slope_array[:,i_rad_distrib],
                     y2=med_slope_array[:,i_rad_distrib]-slope_err_array[:,3],
                     color=rad_distrib_colors[i_rad_distrib], alpha=0.2)

plt.axhline(true_gradient_all, c="red", lw=3, label="True +/- 0.01 dex/kpc", zorder=0)
plt.axhspan(true_gradient_all - 0.01, true_gradient_all + 0.01, color="red", alpha=0.1, zorder=0)
#plt.axhline(true_gradient_disk, c="green", lw=3, ls=':', label="True", zorder=0)
#plt.axhspan(true_gradient_disk - 0.01, true_gradient_disk + 0.01, color="green", alpha=0.1, zorder=0)
plt.legend(title='Frac of stars in radial bins')
plt.xlim([2,5.7])
plt.ylim(gradient_rng)
plt.xlabel(r'log$_{10}$(N$_{\rm stars}$)')
plt.ylabel('Gradient [dex/kpc]')
plt.title(r'$\sigma_d$/$d$={:.1f}%, $\sigma_X$={:.2f} dex'.format(dist_unc0*100, abund_unc0))
# Out:
# Text(0.5, 1.0, '$\\sigma_d$/$d$=15.0%, $\\sigma_X$=0.05 dex')

# %% [markdown]
# ## Results
# - Distance uncertainties always scatter things to flatter gradients. <b>HAVE TO GET GOOD DISTANCES.</b>
# - The measured gradient doesn't change as the total number of stars increases past $\log{N} \sim 4.2$. The precision increases a bit past that, but the value itself stays flat.
# - This is likely because these gradients are measured from binned medians, which alleviates the underlying density distribution. If we measure directly from the points (as a simple linear fit), everything is systematically shifted higher -- having the outer disk stars still helps, but not as much.
# - We need stars beyond the solar circle to pin down the disk gradient, outside of the bulge. We don't need <i>many</i> of them, but we do <i>need</i> them.
# - To the above, even 5% of the sample with R>8 kpc helps. 5% of 15,000 is 750 stars.
# - TO DO: Update the fitting to include both distance and abundance uncertainties.

# %% [markdown]
# ## Test effects of other choices

# %% [markdown]
# ### What if we have a bias against metal-poor stars?
#
# - Assessed by adding "all_stars['Fe/H_evolved'] > X" to the cell above.
# - $\rm X=-1$ dex: no change
# - $\rm X=-0.5$ dex: shifts gradients very slightly flatter at the level of 0.002 dex/kpc, does not change behavior due to the radial distribution of the sample
# - $\rm X=-0.25$ dex: shifts all gradients to $\sim 0.015$ dex/kpc too high, likely because it's preferentially removing those valuable outer disk stars.

# %% [markdown]
# ### What if we don't have APO?
#
# - Assessed by adding "np.logical_or.reduce([all_stars['l'] < 10., all_stars['l'] > 180.])" to the cell above.
# - No change, <i>given the same total sample size</i>
# - Because LCO can see so much of the disk, for a single gradient measurement, APO is not essential.

# %% [markdown]
# ### What if we can't reach the midplane at inner longitudes?
#
# - Assessed by restricting to $|b| > 0.2^\circ$ inside $|l| = 10^\circ$: "np.logical_or.reduce([abs(all_stars['b']) > 0.2, np.logical_and.reduce([all_stars['l'] > 10., all_stars['l'] < 350.])])"
# - Limiting to 0.2 deg doesn't change anything.
# - If I go all the way up to $|b|>2^\circ$ for that inner region, things do get flatter, because the thick disk has an intrinsically flatter gradient. But the area outside of $|l| = 10^\circ$ is large enough to provide low $|Z|$ stars as long as we can observe lots of $b \sim 0^\circ$ there.
